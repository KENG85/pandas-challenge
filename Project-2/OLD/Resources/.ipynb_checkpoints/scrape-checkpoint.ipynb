# %%
from bs4 import BeautifulSoup
import requests

# %%
# In[2]:
# URL of page to be scraped
url = 'https://pro-football-reference.com/years/2006/draft.htm'

# %%
# In[3]:
# Retrieve page with the requests module
response = requests.get(url)

# %%
# In[4]:
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# In[5]:
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/pfr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
#    <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202006191" rel="dns-prefetch"/>
#    <!-- no:cookie fast load the css.           -->
#    <script>
#     function gup(n) {n = n.replace(/[\[]/, '\\[').replace(/[\]]/, '\\]'); var r = new RegExp('[\\?&]'+n+'=([^&#]*)'); var re = r.exec(location.search);   return re === null?'':decodeURIComponent(re[1].replace(/\+/g,' '));}; document.srdev = gup('srdev')
#    </script>
#    <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
#    <style>
# ...

# %%
# In[6]:
# results are returned as an iterable list
results = soup.find_all('a', text="College Stats")
results
# Out:
# [<a href="http://www.sports-reference.com/cfb/players/mario-williams-1.html">College Stats</a>,
#  <a href="http://www.sports-reference.com/cfb/players/reggie-bush-1.html">College Stats</a>,
#  <a href="http://www.sports-reference.com/cfb/players/vince-young-1.html">College Stats</a>,
#  <a href="http://www.sports-reference.com/cfb/players/aj-hawk-1.html">College Stats</a>,
#  <a href="http://www.sports-reference.com/cfb/players/vernon-davis-1.html">College Stats</a>,
#  <a href="http://www.sports-reference.com/cfb/players/michael-huff-1.html">College Stats</a>,
#  <a href="http://www.sports-reference.com/cfb/players/donte-whitner-1.html">College Stats</a>,
#  <a href="http://www.sports-reference.com/cfb/players/ernie-sims-1.html">College Stats</a>,
#  <a href="http://www.sports-reference.com/cfb/players/matt-leinart-1.html">College Stats</a>,
#  <a href="http://www.sports-reference.com/cfb/players/jay-cutler-1.html">College Stats</a>,
# ...

# %%
url = "https://pro-football-reference.com/years/2006/draft.htm"
browser.visit(url)

link = soup.find_all('a', text="College Stats")
college_stats = []

for x in range(len(link)):   
    stats_url = {}
    browser.links.find_by_partial_text("College Stats")[x].click()
    time.sleep(3)
    #link = soup.find_all('a', class_="itemLink product-item")
    footer = browser.find("tr", class_="bold").text
    #hemisphere_img["Img_url"] = sample['href']
   
    stats_url["career_stats"] = footer
    
    college_stats.append(stats_url)
    browser.back()
        
#hemisphere_img
college_stats
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-fe1240795be8> in <module>
# ----> 1 len(tfoot)
#
# TypeError: object of type 'NoneType' has no len()

# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs, NavigableString as ns
from IPython.display import display_html
import pandas as pd
import requests
import time
import re
from sys import platform
from urllib.parse import urlsplit
from bs4 import BeautifulSoup 
import pandas as pd
from pprint import pprint

# %%
def init_Browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
    return Browser("chrome", **executable_path, headless=False)
browser = init_Browser()
players = {}

# %%
url = "https://pro-football-reference.com/years/2006/draft.htm"
browser.visit(url)

#continue_link = driver.find_element_by_link_text('Continue')
links = browser.links.find_element_by_link_text("College Stats")

html = browser.html
soup = BeautifulSoup(html, "html.parser")

#tfoot = soup.find("tfoot", [0])
#players["college stats"] = tfoot
links
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-96407de815fe> in <module>
#       3
#       4 #continue_link = driver.find_element_by_link_text('Continue')
# ----> 5 links = browser.links.find_element_by_link_text("College Stats")
#       6
#       7 html = browser.html
#
# AttributeError: 'FindLinks' object has no attribute 'find_element_by_link_text'

# %%
len(title)
# Out:
# 0
