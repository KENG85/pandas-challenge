# %%
import pandas as pd

# %%
nfl = pd.read_csv("nfl_players.csv", header=[1])
nfl.head()
# Out:
#                  name first_name     last_name   birth_city birth_state  \
# 0       Isaako Aaitui     Isaako        Aaitui          NaN         NaN
# 1         Faye Abbott       Faye        Abbott    Clearport          OH
# 2        Vince Abbott      Vince        Abbott       London         NaN
# 3       Duke Abbruzzi       Duke      Abbruzzi       Warren          RI
# 4  Karim Abdul-Jabbar      Karim  Abdul-Jabbar  Los Angeles          CA
#
#   birth_country  birth_date       college      draft_team draft_round  ...  \
# 0           NaN   1/25/1987           NaN             NaN         NaN  ...
# 1           USA  1895-08-16      Syracuse             NaN         NaN  ...
# 2       England   5/31/1958    Washington             NaN         NaN  ...
# 3           USA    8/3/1917  Rhode Island             NaN         NaN  ...
# 4           USA   6/28/1974          UCLA  Miami Dolphins         3rd  ...
#
#   Unnamed: 246  Unnamed: 247 Unnamed: 248 Unnamed: 249  Unnamed: 250  \
# ...

# %%
nfl = nfl[["name", "first_name","last_name","birth_city", "birth_state", "birth_country", "birth_date", 
         "college", "draft_team", "draft_round", "draft_pick", "draft_year", "position", 
                     "height", "weight", "year_start", "year_end"]]
nfl
# Out:
#                      name first_name     last_name   birth_city birth_state  \
# 0           Isaako Aaitui     Isaako        Aaitui          NaN         NaN
# 1             Faye Abbott       Faye        Abbott    Clearport          OH
# 2            Vince Abbott      Vince        Abbott       London         NaN
# 3           Duke Abbruzzi       Duke      Abbruzzi       Warren          RI
# 4      Karim Abdul-Jabbar      Karim  Abdul-Jabbar  Los Angeles          CA
# ...                   ...        ...           ...          ...         ...
# 23728     Markus Zusevics     Markus      Zusevics          NaN         NaN
# 23729       Jeremy Zuttah     Jeremy        Zuttah       Edison          NJ
# 23730         Merle Zuver      Merle         Zuver        Adams          NE
# 23731         Tony Zuzzio       Tony        Zuzzio    Irvington          NJ
# 23732         Jim Zyntell        Jim       Zyntell       Boston          MA
#
# ...

# %%
nfl_2006 = nfl.loc[(nfl["draft_year"]=="2006.0")]
nfl_2006
# Out:
# Empty DataFrame
# Columns: [name, first_name, last_name, birth_city, birth_state, birth_country, birth_date, college, draft_team, draft_round, draft_pick, draft_year, position, height, weight, year_start, year_end]
# Index: []
